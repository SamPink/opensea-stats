# %%
import database as db
# Out:
# Collection 'apes_sales' doesn't exist.
# Please select one of the following; ['boredapeyachtclub_still_listed', 'lazy-lions_cancellations', 'boredapeyachtclub_cancellations', 'lazy-lions_sales', 'lazy-lions_listings', 'boredapeyachtclub_sales', 'boredapeyachtclub_transfers', 'lazy-lions_transfers', 'boredapeyachtclub_listings']

# %%
sales = db.read_mongo("boredapeyachtclub_sales", return_df=True)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10045 entries, 0 to 10044
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            10045 non-null  object
#  1   sale_id        10045 non-null  int64
#  2   asset_id       10045 non-null  int64
#  3   sale_quantity  10045 non-null  int64
#  4   collection     10045 non-null  object
#  5   image_url      10045 non-null  object
#  6   time           10045 non-null  datetime64[ns]
#  7   event_type     10045 non-null  object
#  8   seller_wallet  10045 non-null  object
#  9   buyer_wallet   10045 non-null  object
#  10  block_hash     10045 non-null  object
#  11  sale_currency  10045 non-null  object
#  12  sale_price     10045 non-null  float64
#  13  sale_date      10045 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(9)
# memory usage: 1.1+ MB

# %%
#convert sale_time to date
sales["sale_date"] = sales["time"].dt.date

# %%
#get the min sale price for each day
sales_min = sales.groupby(["sale_date"])["sale_price"].min()

# %%
import plotly.graph_objects as go

# %%
#plot the min sale price for each day excluding days with no sales
fig = go.Figure(data=[go.Scatter(x=sales_min.index, y=sales_min.values)])
#add 5 day moving average
fig.add_trace(go.Scatter(x=sales_min.index, y=sales_min.rolling(5).mean()))
#name figure floor by day   
fig.update_layout(title_text="Floor Price by Day")
fig.show()

# %%
#plot total ether sold for each day
sales_total = sales.groupby(["sale_date"])["sale_price"].sum()
#plot sales total
fig = go.Figure(data=[go.Scatter(x=sales_total.index, y=sales_total.values)])
#add ten day moving average
fig.add_trace(go.Scatter(x=sales_total.index, y=sales_total.rolling(10).mean()))
#name figure volume by day
fig.update_layout(title_text="Total Ether Sold by Day")
fig.show()

# %%
#get mean price per asset   
sales_mean = sales.groupby(["asset_id"])["sale_price"].mean()

sales_mean.value_counts(bins=50)
# Out:
# (-0.77, 15.38]      1884
# (15.38, 30.76]      1125
# (30.76, 46.14]       926
# (46.14, 61.52]       474
# (61.52, 76.9]        119
# (76.9, 92.28]         48
# (92.28, 107.66]       25
# (107.66, 123.04]      12
# (199.94, 215.32]       4
# (123.04, 138.42]       4
# (415.26, 430.64]       3
# (215.32, 230.7]        3
# (246.08, 261.46]       2
# (384.5, 399.88]        2
# (184.56, 199.94]       2
# (138.42, 153.8]        2
# (153.8, 169.18]        2
# (338.36, 353.74]       1
# (538.3, 553.68]        1
# (522.92, 538.3]        1
# (399.88, 415.26]       1
# (492.16, 507.54]       1
# (753.62, 769.0]        1
# (276.84, 292.22]       1
# (261.46, 276.84]       1
# (169.18, 184.56]       1
# (584.44, 599.82]       0
# (738.24, 753.62]       0
# (722.86, 738.24]       0
# (707.48, 722.86]       0
# (692.1, 707.48]        0
# (676.72, 692.1]        0
# (661.34, 676.72]       0
# (645.96, 661.34]       0
# (630.58, 645.96]       0
# (615.2, 630.58]        0
# (599.82, 615.2]        0
# ...
