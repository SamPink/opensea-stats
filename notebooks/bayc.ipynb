# %%
import opensea.database as Database

# %%
#sales = db.read_mongo("boredapeyachtclub_sales", return_df=True)
#read from mongoDB
ag_sales = Database.read_mongo('ape-gang_sales',return_df=True).drop_duplicates(subset=['asset_id','time'])
ag_old_sales = Database.read_mongo('ape-gang-old_sales',return_df=True).drop_duplicates(subset=['asset_id','time'])
apes=Database.read_mongo('ape-gang-old_traits',return_df=True)

sales = ag_sales.append(ag_old_sales)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22321 entries, 0 to 22298
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_id        22321 non-null  int64
#  1   asset_id       22321 non-null  int64
#  2   sale_quantity  22321 non-null  int64
#  3   collection     22321 non-null  object
#  4   image_url      22321 non-null  object
#  5   time           22321 non-null  datetime64[ns]
#  6   event_type     22321 non-null  object
#  7   seller_wallet  22321 non-null  object
#  8   buyer_wallet   22321 non-null  object
#  9   block_hash     22321 non-null  object
#  10  sale_currency  22321 non-null  object
#  11  sale_price     22321 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 2.2+ MB

# %%
#convert sale_time to date
sales["sale_date"] = sales["time"].dt.date

# %%
#get the min sale price for each day
sales_min = sales.groupby(["sale_date"])["sale_price"].min()

# %%
import plotly.graph_objects as go

# %%
#plot the min sale price for each day excluding days with no sales
fig = go.Figure(data=[go.Scatter(x=sales_min.index, y=sales_min.values)])
#add 5 day moving average
fig.add_trace(go.Scatter(x=sales_min.index, y=sales_min.rolling(5).mean()))
#name figure floor by day   
fig.update_layout(title_text="Floor Price by Day")
fig.show()

# %%
#plot total ether sold for each day
sales_total = sales.groupby(["sale_date"])["sale_price"].sum()
#plot sales total
fig = go.Figure(data=[go.Scatter(x=sales_total.index, y=sales_total.values)])
#add ten day moving average
fig.add_trace(go.Scatter(x=sales_total.index, y=sales_total.rolling(10).mean()))
#name figure volume by day
fig.update_layout(title_text="Total Ether Sold by Day")
fig.show()

# %%
#get mean 
sales_mean = sales.groupby(["sale_date"])["sale_price"].mean()

#plot sales mean
fig = go.Figure(data=[go.Scatter(x=sales_mean.index, y=sales_mean.values)])
#add ten day moving average
fig.add_trace(go.Scatter(x=sales_mean.index, y=sales_mean.rolling(10).mean()))
#name figure volume by day
fig.update_layout(title_text="Mean Price per Asset")
fig.show()

# %%
sales_mean
# Out:
# sale_date
# 2021-07-19    0.085044
# 2021-07-20    0.124350
# 2021-07-21    0.081291
# 2021-07-22    0.078561
# 2021-07-23    0.069769
#                 ...
# 2022-01-25    0.358182
# 2022-01-26    0.289112
# 2022-01-27    0.362643
# 2022-01-28    0.366370
# 2022-01-29    0.336363
# Name: sale_price, Length: 195, dtype: float64
